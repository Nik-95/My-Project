# %% [markdown]
# ## Retail_Data_Analysis

# %%
#rough
# import of diff lib

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# file import
customer_data = pd.read_csv('Customer.csv')

# %%
customer_data.head(5)
# Out:
#    customer_Id         DOB Gender  city_code
# 0       268408  02-01-1970      M        4.0
# 1       269696  07-01-1970      F        8.0
# 2       268159  08-01-1970      F        8.0
# 3       270181  10-01-1970      F        2.0
# 4       268073  11-01-1970      M        1.0

# %%
customer_data.describe()
# Out:
#          customer_Id    city_code
# count    5647.000000  5645.000000
# mean   271037.281034     5.472631
# std      2451.261711     2.859918
# min    266783.000000     1.000000
# 25%    268912.000000     3.000000
# 50%    271028.000000     5.000000
# 75%    273180.000000     8.000000
# max    275265.000000    10.000000

# %%
customer_data.isnull().sum()
# Out:
# customer_Id    0
# DOB            0
# Gender         2
# city_code      2
# dtype: int64

# %%
customer_data[customer_data.isnull().any(axis=1)]
# Out:
#      customer_Id         DOB Gender  city_code
# 24        267199  14-02-1970    NaN        2.0
# 87        271626  02-06-1970    NaN        6.0
# 115       268447  14-07-1970      M        NaN
# 149       268709  09-09-1970      F        NaN

# %%
customer_data.loc[customer_data['customer_Id'] == 267199, 'Gender'] = customer_data.loc[customer_data['customer_Id'] == 267199, 'Gender'].fillna('M')

# %%
customer_data[customer_data.isnull().any(axis=1)]
# Out:
#      customer_Id         DOB Gender  city_code
# 87        271626  02-06-1970    NaN        6.0
# 115       268447  14-07-1970      M        NaN
# 149       268709  09-09-1970      F        NaN

# %%
customer_data.loc[customer_data['customer_Id'] == 267199]
# Out:
#     customer_Id         DOB Gender  city_code
# 24       267199  14-02-1970      M        2.0

# %%
# Convert data type

        # DOB------>object------>Datetime

customer_data['DOB'] = pd.to_datetime(customer_data['DOB'])
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_16808\2710634987.py:5: UserWarning: Parsing '15-01-1970' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   customer_data['DOB'] = pd.to_datetime(customer_data['DOB'])
# C:\Users\mohit\AppData\Local\Temp\ipykernel_16808\2710634987.py:5: UserWarning: Parsing '16-01-1970' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   customer_data['DOB'] = pd.to_datetime(customer_data['DOB'])
# C:\Users\mohit\AppData\Local\Temp\ipykernel_16808\2710634987.py:5: UserWarning: Parsing '18-01-1970' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   customer_data['DOB'] = pd.to_datetime(customer_data['DOB'])
# C:\Users\mohit\AppData\Local\Temp\ipykernel_16808\2710634987.py:5: UserWarning: Parsing '21-01-1970' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# ...

# %%
import pandas as pd

# create the dataframe
data = {'city_code': [1.0, 1.0, 2.0, 2.0, 3.0, 3.0, 4.0, 4.0, 5.0, 5.0, 6.0, 6.0, 7.0, 7.0, 8.0, 8.0, 9.0, 9.0, 10.0, 10.0],
        'Gender': ['F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M', 'F', 'M'],
        'count': [288, 263, 261, 302, 271, 324, 272, 310, 287, 299, 265, 260, 293, 282, 247, 315, 286, 260, 282, 276]}

#df = pd.DataFrame(data)

# calculate the total count of males and females in each city
city_totals = customer_data.groupby('city_code')['count'].sum()

# calculate the probability of selecting a male and a female from each city
customer_data['probability'] = customer_data.apply(lambda row: row['count'] / city_totals[row['city_code']], axis=1)

# print the probabilities for each city
print(customer_data[['city_code', 'probability']]) #.drop_duplicates())
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13160\1242801576.py in <module>
#       9
#      10 # calculate the total count of males and females in each city
# ---> 11 city_totals = customer_data.groupby('city_code')['count'].sum()
#      12
#      13 # calculate the probability of selecting a male and a female from each city
#
# ~\anaconda3\lib\site-packages\pandas\core\groupby\generic.py in __getitem__(self, key)
#    1336                 stacklevel=find_stack_level(),
#    1337             )
# -> 1338         return super().__getitem__(key)
#    1339
#    1340     def _gotitem(self, key, ndim: int, subset=None):
#
# ~\anaconda3\lib\site-packages\pandas\core\base.py in __getitem__(self, key)
#     248         else:
#     249             if key not in self.obj:
# --> 250                 raise KeyError(f"Column not found: {key}")
# ...

# %%
# Convert data type

        # city_code -----> float64 ------> float8
    
customer_data['city_code'] = customer_data['city_code'].astype()
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_16808\3033390746.py in <module>
#       3         # city_code -----> float64 ------> float8
#       4
# ----> 5 customer_data['city_code'] = customer_data['city_code'].astype('int8')
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
# Gender_count

x = customer_data['Gender'].value_counts()
x
# Out:
# M    2892
# F    2753
# Name: Gender, dtype: int64

# %%
# city_code

y = customer_data['city_code'].value_counts()
y
# Out:
# 3.0     595
# 5.0     586
# 4.0     582
# 7.0     575
# 2.0     564
# 8.0     562
# 10.0    558
# 1.0     551
# 9.0     546
# 6.0     526
# Name: city_code, dtype: int64

# %%
p = x/len(customer_data)
p
# Out:
# M    0.512130
# F    0.487515
# Name: Gender, dtype: float64

# %%
a = y/ len(customer_data)
a
# Out:
# 3.0     0.105366
# 5.0     0.103772
# 4.0     0.103064
# 7.0     0.101824
# 2.0     0.099876
# 8.0     0.099522
# 10.0    0.098814
# 1.0     0.097574
# 9.0     0.096689
# 6.0     0.093147
# Name: city_code, dtype: float64

# %%
count=customer_data.groupby(['city_code','Gender']).size()
count = count.unstack()

# %%
count
# Out:
# Gender       F    M
# city_code
# 1.0        288  263
# 2.0        261  302
# 3.0        271  324
# 4.0        272  310
# 5.0        287  299
# 6.0        265  260
# 7.0        293  282
# 8.0        247  315
# 9.0        286  260
# 10.0       282  276

# %%
y
# Out:
# 3.0     595
# 5.0     586
# 4.0     582
# 7.0     575
# 2.0     564
# 8.0     562
# 10.0    558
# 1.0     551
# 9.0     546
# 6.0     526
# Name: city_code, dtype: int64

# %%
customer_data[customer_data.isnull().any(axis=1)]
# Out:
#      customer_Id        DOB Gender  city_code
# 24        267199 1970-02-14    NaN        2.0
# 87        271626 1970-02-06    NaN        6.0
# 115       268447 1970-07-14      M        NaN
# 149       268709 1970-09-09      F        NaN

# %%
stores.AcqCostPercust[stores.AcqCostPercust.isna()] = stores.AcqCostPercust.mean()
