# %% [markdown]
# # Retail Data Anslysis Solved

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
customer_data = pd.read_csv('Customer.csv')

# %%
customer_data
# Out:
#       customer_Id         DOB Gender  city_code
# 0          268408  02-01-1970      M        4.0
# 1          269696  07-01-1970      F        8.0
# 2          268159  08-01-1970      F        8.0
# 3          270181  10-01-1970      F        2.0
# 4          268073  11-01-1970      M        1.0
# ...           ...         ...    ...        ...
# 5642       274474  19-12-1992      M        2.0
# 5643       267666  24-12-1992      M        6.0
# 5644       270476  25-12-1992      F        3.0
# 5645       269626  27-12-1992      F        5.0
# 5646       274308  29-12-1992      F        5.0
#
# [5647 rows x 4 columns]

# %%
customer_data['DOB'] = pd.to_datetime(customer_data['DOB'])
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_11180\4069155985.py:1: UserWarning: Parsing '15-01-1970' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   customer_data['DOB'] = pd.to_datetime(customer_data['DOB'])
# C:\Users\mohit\AppData\Local\Temp\ipykernel_11180\4069155985.py:1: UserWarning: Parsing '16-01-1970' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   customer_data['DOB'] = pd.to_datetime(customer_data['DOB'])
# C:\Users\mohit\AppData\Local\Temp\ipykernel_11180\4069155985.py:1: UserWarning: Parsing '18-01-1970' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
#   customer_data['DOB'] = pd.to_datetime(customer_data['DOB'])
# C:\Users\mohit\AppData\Local\Temp\ipykernel_11180\4069155985.py:1: UserWarning: Parsing '21-01-1970' in DD/MM/YYYY format. Provide format or specify infer_datetime_format=True for consistent parsing.
# ...

# %%
#df.fillna(0, inplace=True)

customer_data['Gender'].fillna('M', inplace=True)

# %%
customer_data['city_code'].fillna(5, inplace=True)

# %%
customer_data['city_code'] = customer_data['city_code'].astype('int8')

# %%
customer_data.isnull().sum()
# Out:
# customer_Id    0
# DOB            0
# Gender         0
# city_code      0
# dtype: int64

# %%
# Fill all the missing valeus in acqcostpercust with mean 

#stores.AcqCostPercust[stores.AcqCostPercust.isna()] = stores.AcqCostPercust.mean()

# %%
customer_data.city_code[customer_data.city_code.isna()] = customer_data.city_code.mean()
# Out:
# C:\Users\mohit\AppData\Local\Temp\ipykernel_11180\2114175650.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_data.city_code[customer_data.city_code.isna()] = customer_data.city_code.mean()

# %%
customer_data.city_code.mean()
# Out:
# 5.472463254825571

# %%
print(customer_data.dtypes)
# Out:
# customer_Id             int64
# DOB            datetime64[ns]
# Gender                 object
# city_code                int8
# dtype: object

# %%
customer_data
# Out:
#       customer_Id        DOB Gender  city_code
# 0          268408 1970-02-01      M          4
# 1          269696 1970-07-01      F          8
# 2          268159 1970-08-01      F          8
# 3          270181 1970-10-01      F          2
# 4          268073 1970-11-01      M          1
# ...           ...        ...    ...        ...
# 5642       274474 1992-12-19      M          2
# 5643       267666 1992-12-24      M          6
# 5644       270476 1992-12-25      F          3
# 5645       269626 1992-12-27      F          5
# 5646       274308 1992-12-29      F          5
#
# [5647 rows x 4 columns]

# %%
customer_data['customer_Id'].duplicated
# Out:
# <bound method Series.duplicated of 0       268408
# 1       269696
# 2       268159
# 3       270181
# 4       268073
#          ...
# 5642    274474
# 5643    267666
# 5644    270476
# 5645    269626
# 5646    274308
# Name: customer_Id, Length: 5647, dtype: int64>

# %%
customer_data.describe()
# Out:
#          customer_Id    city_code
# count    5647.000000  5647.000000
# mean   271037.281034     5.472463
# std      2451.261711     2.859425
# min    266783.000000     1.000000
# 25%    268912.000000     3.000000
# 50%    271028.000000     5.000000
# 75%    273180.000000     8.000000
# max    275265.000000    10.000000

# %%
customer_data.isnull().sum()
# Out:
# customer_Id    0
# DOB            0
# Gender         0
# city_code      0
# dtype: int64

# %%
customer_data
# Out:
#       customer_Id        DOB Gender  city_code  Age
# 0          268408 1970-02-01      M          4   53
# 1          269696 1970-07-01      F          8   52
# 2          268159 1970-08-01      F          8   52
# 3          270181 1970-10-01      F          2   52
# 4          268073 1970-11-01      M          1   52
# ...           ...        ...    ...        ...  ...
# 5642       274474 1992-12-19      M          2   30
# 5643       267666 1992-12-24      M          6   30
# 5644       270476 1992-12-25      F          3   30
# 5645       269626 1992-12-27      F          5   30
# 5646       274308 1992-12-29      F          5   30
#
# [5647 rows x 5 columns]

# %%
import datetime as dt
current_date = dt.datetime.today()

# %%
customer_data['age'] = ((current_date - customer_data['DOB']) / (365.25)).astype(int)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11180\189289607.py in <module>
# ----> 1 customer_data['age'] = ((current_date - customer_data['DOB']) / (365.25)).astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 419         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     420
# ...

# %%
Age_gr = customer_data.groupby('Age')['city_code'].sum()

# %%
customer_data
# Out:
#       customer_Id        DOB Gender  city_code  Age
# 0          268408 1970-02-01      M          4   53
# 1          269696 1970-07-01      F          8   52
# 2          268159 1970-08-01      F          8   52
# 3          270181 1970-10-01      F          2   52
# 4          268073 1970-11-01      M          1   52
# ...           ...        ...    ...        ...  ...
# 5642       274474 1992-12-19      M          2   30
# 5643       267666 1992-12-24      M          6   30
# 5644       270476 1992-12-25      F          3   30
# 5645       269626 1992-12-27      F          5   30
# 5646       274308 1992-12-29      F          5   30
#
# [5647 rows x 5 columns]

# %%
Age_gr
# Out:
# Age
# 30    1011.0
# 31    1282.0
# 32    1291.0
# 33    1425.0
# 34    1438.0
# 35    1507.0
# 36    1248.0
# 37    1314.0
# 38    1282.0
# 39    1214.0
# 40    1347.0
# 41    1288.0
# 42    1479.0
# 43    1427.0
# 44    1427.0
# 45    1271.0
# 46    1262.0
# 47    1437.0
# 48    1361.0
# 49    1344.0
# 50    1246.0
# 51    1402.0
# 52    1223.0
# 53     377.0
# Name: city_code, dtype: float64

# %% [markdown]
# # Transaction Data import

# %%
transaction_data = pd.read_csv('Transactions.csv')

# %%
transaction_data
# Out:
#        transaction_id  cust_id   tran_date  prod_subcat_code  prod_cat_code  \
# 0         80712190438   270351  28-02-2014                 1              1
# 1         29258453508   270384  27-02-2014                 5              3
# 2         51750724947   273420  24-02-2014                 6              5
# 3         93274880719   271509  24-02-2014                11              6
# 4         51750724947   273420  23-02-2014                 6              5
# ...               ...      ...         ...               ...            ...
# 23048     94340757522   274550  25-01-2011                12              5
# 23049     89780862956   270022  25-01-2011                 4              1
# 23050     85115299378   271020  25-01-2011                 2              6
# 23051     72870271171   270911  25-01-2011                11              5
# 23052     77960931771   271961  25-01-2011                11              5
#
#        Qty  Rate      Tax  total_amt Store_type
# ...

# %%
transaction_data.dtypes
# Out:
# transaction_id                int64
# customer_Id                   int64
# tran_date            datetime64[ns]
# prod_sub_cat_code             int64
#                               int64
# Qty                           int64
# Rate                          int64
# Tax                         float64
# total_amt                   float64
# Store_type                   object
# sales                       float64
# dtype: object

# %%
t_count = transaction_data[transaction_data['total_amt']<0]

# %%
t_count['total_amt'].value_counts().sum()
# Out:
# 2177

# %%
t_count['total_amt'].sum()
# Out:
# -5874113.7

# %%
len(t_count)
# Out:
# 2177

# %%
data_tableXa
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11180\179280494.py in <module>
# ----> 1 data_tableXa
#
# NameError: name 'data_tableXa' is not defined

# %%
#rename colmuns

transaction_data = transaction_data.rename(columns={'cust_id':'customer_Id'})

# %%
#prod_subcat_code ------>prod_sub_cat_code             
#prod_cat_code -----------> prod_cat_code

transaction_data =transaction_data.rename(columns={'prod_cat_code':''})

# %%
transaction_data =transaction_data.rename(columns={'prod_subcat_code':'prod_sub_cat_code'})

# %%
# Data type conversion

# %%
transaction_data['prod_cat_code'] = transaction_data['prod_cat_code'].astype('int8')

# %%
transaction_data['Rate'] = transaction_data['Rate'].astype('float64')

# %%
transaction_data.dtypes

# %%
transaction_data.isnull()

# %%
transaction_data.duplicated

# %%
transaction_data.describe()
# Out:
#        transaction_id    customer_Id  prod_sub_cat_code                \
# count    2.305300e+04   23053.000000       23053.000000  23053.000000
# mean     5.007348e+10  271021.746497           6.149091      3.763632
# std      2.898194e+10    2431.692059           3.726372      1.677016
# min      3.268991e+06  266783.000000           1.000000      1.000000
# 25%      2.493864e+10  268935.000000           3.000000      2.000000
# 50%      5.009313e+10  270980.000000           5.000000      4.000000
# 75%      7.533000e+10  273114.000000          10.000000      5.000000
# max      9.998755e+10  275265.000000          12.000000      6.000000
#
#                 Qty          Rate           Tax     total_amt         sales
# count  23053.000000  23053.000000  23053.000000  23053.000000  23053.000000
# mean       2.432395    636.369713    248.667192   2107.308002   2362.117081
# std        2.268406    622.363498    187.177773   2507.561264   2018.821206
# ...

# %%
5*365/7*20
# Out:
# 5214.285714285715

# %%
transaction_data.sort_values('sales', ascending=False)
# Out:
#        transaction_id  customer_Id  tran_date  prod_sub_cat_code     Qty  \
# 11292     47747209902       270667 2012-08-23                  5  3    5
# 13009     53187031441       272954 2012-05-26                  2  6    5
# 6864      94956713072       271944 2013-03-23                  4  2    5
# 20123     96892547017       274854 2011-06-21                  3  2    5
# 976       82213567288       270087 2014-04-01                 11  6    5
# ...               ...          ...        ...                ... ..  ...
# 21233     75548907294       268584 2011-04-24                 12  6   -3
# 8481      63251224120       271381 2013-03-01                  7  5   -4
# 8475       7576355995       268250 2013-03-01                  4  1   -5
# 8473      55284015378       271465 2013-03-01                  4  2   -4
# 0         80712190438       270351 2014-02-28                  1  1   -5
#
#        Rate      Tax  total_amt      Store_type     sales
# ...

# %%
transaction_data['sales'] = transaction_data['total_amt'] > 0

# %%
def modify_value(x):
    if x < 0:
        return 0
    else:
        return x
# apply the function to the 'total_amt' column using the apply() method
transaction_data['sales'] = transaction_data['total_amt'].apply(modify_value)

# %%
transaction_data['sold'] = transaction_data

# %%
a = transaction_data.info()

# %%
transaction_data['tran_date'].dt.year

# %% [markdown]
# # Product_ Cat

# %%
prod_data = pd.read_csv('prod_cat_info.csv')

# %%
prod_data

# %%
prod_data.sort_index(1)

# %%
prod_data.isnull()

# %%
prod_data.describe()

# %%
prod_data.dtypes

# %%
prod_data['prod_cat_code'] = prod_data['prod_cat_code'].astype('int8')

# %%
prod_data['prod_sub_cat_code'] = prod_data['prod_sub_cat_code'].astype('int8')

# %%
prod_data.dtypes

# %% [markdown]
# # Join

# %%
result = pd.merge(df1, df2, on='common_column', how='left')

# %%
data_table1 = pd.merge(customer_data,transaction_data, on='customer_Id', how='inner') \ 
                .

# %%
data_table1

# %%
prod_data.head(1)
# Out:
#    prod_cat_code  prod_cat  prod_sub_cat_code prod_subcat
# 0              1  Clothing                  4        Mens

# %%
customer_data.isnull().sum()

# %%
transaction_data.head(1)
# Out:
#    transaction_id  customer_Id  tran_date  prod_sub_cat_code     Qty  Rate  \
# 0     80712190438       270351 2014-02-28                  1  1   -5  -772
#
#      Tax  total_amt Store_type  sales
# 0  405.3    -4265.3     e-Shop    0.0

# %%
prod_data.isnull().sum()

# %%
#stores.describe(include='all',percentiles=[0.1,0.5,0.7,0.9])

customer_data.describe(percentiles=[0.1,0.5,0.7,0.9],include='all')

# %%
data_tableX= pd.merge(customer_data, transaction_data, left_on=['customer_Id'], right_on=['customer_Id'], how='inner') \
           .merge(prod_data, left_on=['prod_sub_cat_code'], right_on=['prod_sub_cat_code'], how='inner')

# %%
data_tableX.head(2)
# Out:
#    customer_Id        DOB Gender  city_code  Age  transaction_id  tran_date  \
# 0       268408 1970-02-01      M          4   53     87243835584 2014-01-13
# 1       275152 1970-01-16      M          4   53     73109425404 2011-03-25
#
#    prod_sub_cat_code     Qty  Rate     Tax  total_amt Store_type     sales  \
# 0                  7  5    5   187  98.175   1033.175   TeleShop  1033.175
# 1                  7  5    2   464  97.440   1025.440     e-Shop  1025.440
#
#    prod_cat_code prod_cat prod_subcat
# 0              5    Books     Fiction
# 1              5    Books     Fiction

# %%
xy.value_counts()
# Out:
# Gender  prod_cat          prod_subcat
# M       Bags              Women                  2063
#         Footwear          Kids                   2063
#         Clothing          Mens                   2063
#         Electronics       Mobiles                2063
# F       Footwear          Kids                   1939
#         Clothing          Mens                   1939
#         Bags              Women                  1939
#         Electronics       Mobiles                1939
#         Footwear          Women                  1553
#         Books             Comics                 1553
#         Clothing          Kids                   1553
# M       Clothing          Women                  1526
#         Books             Non-Fiction            1526
#         Bags              Mens                   1526
#         Electronics       Audio and video        1526
#         Footwear          Mens                   1526
#         Home and kitchen  Kitchen                1526
# ...

# %%
rrr = data_tableX.loc[:, ['prod_cat', 'Gender']]

# %%
rrr['t_con'] = rrr.value_counts()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _reindex_for_setitem(value, index)
#   11002     try:
# > 11003         reindexed_value = value.reindex(index)._values
#   11004     except ValueError as err:
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in reindex(self, *args, **kwargs)
#    4671             kwargs.update({"index": index})
# -> 4672         return super().reindex(**kwargs)
#    4673
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in reindex(self, *args, **kwargs)
#    4965         # perform the reindex on the axes
# -> 4966         return self._reindex_axes(
#    4967             axes, level, limit, tolerance, method, fill_value, copy
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _reindex_axes(self, axes, level, limit, tolerance, method, fill_value, copy)
# ...

# %%
rrr.dtypes
# Out:
# prod_cat    object
# Gender      object
# dtype: object

# %%
xyz = data_tableX.loc[:, ['Gender','prod_cat']]

# %%
# assuming your data frame is called `df` and contains columns for `gender` and `product`
# create the pivot table with counts


pivot_table = pd.pivot_table(data_tableX, index='prod_cat', columns='Gender', aggfunc='count')

print(pivot_table)
# Out:
#                                Age         DOB         Qty        Rate        \
# Gender               F     M     F     M     F     M     F     M     F     M
# prod_cat
# Bags              3363  3589  3363  3589  3363  3589  3363  3589  3363  3589
# Books             6004  6175  6004  6175  6004  6175  6004  6175  6004  6175
# Clothing          4916  5103  4916  5103  4916  5103  4916  5103  4916  5103
# Electronics       4795  5115  4795  5115  4795  5115  4795  5115  4795  5115
# Footwear          4916  5103  4916  5103  4916  5103  4916  5103  4916  5103
# Home and kitchen  3959  4128  3959  4128  3959  4128  3959  4128  3959  4128
#
#                   ... prod_subcat       sales       total_amt       tran_date  \
# Gender            ...           F     M     F     M         F     M         F
# prod_cat          ...
# Bags              ...        3363  3589  3363  3589      3363  3589      3363
# Books             ...        6004  6175  6004  6175      6004  6175      6004
# ...

# %%
25/100

# %%
50/100

# %%
transaction_data.median()

# %%
np.median(transaction_data)

# %%
xy =data_table1.select_dtypes(include='object')

# %%
xy.head(5)

# %%
xy.count()

# %%
abc=xy.groupby([ 'Store_type', 'Gender'])

# %%
abc.value_counts()

# %%
print(abc)

# %%
data_table1.head()

# %%
data_table1['Year'] = data_table1.tran_date.dt.year

# %%
data_table1['Day_Name'] = data_table1.tran_date.dt.strftime("%A")

# %%
plt.hist(x=data_table1.Day_Name, rwidth=0.9)
plt.show()

# %%
data_table1.groupby('Year').head(1)

# %%
a.value_counts()

# %%
import pandas as pd
import matplotlib.pyplot as plt

# create a sample DataFrame
df = pd.DataFrame({'date': ['2021-01-01', '2021-02-01', '2022-01-01', '2022-02-01'],
                   'sales': [100, 200, 150, 250]})

# convert the date column to datetime format
df['date'] = pd.to_datetime(df['date'])

# group the sales data by year and sum the values
sales_by_year = df.groupby(df['date'].dt.year)['sales'].sum()

# plot a line chart of the sales data
plt.plot(sales_by_year.index, sales_by_year.values)

# add labels and title to the chart
plt.xlabel('Year')
plt.ylabel('Sales')
plt.title('Yearly Sales Data')

# display the chart
plt.show()

# %%
sold = data_table1.groupby(data_table1['Year'])['total_amt'].sum()

# %%
sold.head(5)

# %%
plt.plot(sales_by_year.index, sales_by_year.values)

# %%
plt.plot(sold.values, sold.index )
#plt.xticks(ticks=[2011,2012,2013,2014])

# %%
plt.hist(x=data_table1.total_amt, y=data_table1.Year)

# %%
data_table1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11180\1818016719.py in <module>
# ----> 1 data_table1
#
# NameError: name 'data_table1' is not defined
